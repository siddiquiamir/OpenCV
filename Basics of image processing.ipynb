# %% [markdown]
# # Basics of image processing

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open("dog-image.jpg")

# %%
type(img)
# Out:
# PIL.WebPImagePlugin.WebPImageFile

# %%
img_arr = np.asarray(img)
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (2250, 3000, 3)

# %%
img_arr
# Out:
# array([[[110, 108,  54],
#         [110, 108,  54],
#         [110, 108,  54],
#         ...,
#         [114, 112,  56],
#         [114, 112,  56],
#         [114, 112,  56]],
#
#        [[110, 108,  54],
#         [110, 108,  54],
#         [110, 108,  54],
#         ...,
#         [114, 112,  56],
#         [114, 112,  56],
#         [114, 112,  56]],
#
#        [[110, 108,  54],
#         [110, 108,  54],
#         [110, 108,  54],
#         ...,
#         [114, 112,  56],
#         [114, 112,  56],
#         [114, 112,  56]],
#
#        ...,
#
#        [[100, 100,  43],
#         [101, 101,  44],
#         [100, 100,  43],
#         ...,
#         [119, 108,  62],
#         [119, 108,  62],
#         [119, 108,  62]],
#
#        [[101, 101,  44],
#         [102, 102,  45],
#         [ 97,  99,  42],
#         ...,
#         [118, 107,  60],
#         [118, 107,  60],
#         [119, 108,  62]],
#
#        [[101, 101,  44],
#         [102, 102,  45],
#         [ 97,  99,  42],
# ...

# %%
plt.imshow(img_arr)

# %%
img_arr.shape
# Out:
# (2250, 3000, 3)
